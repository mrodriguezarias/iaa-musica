# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Rock':1, 'Instrumental':2, 'Folk':3}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Rock', 2: 'Instrumental', 3: 'Folk'}

# %%
npzfile = np.load('shuffled_train_fixed.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (3198, 640, 128) (3198, 4)

# %%
npzfile = np.load('shuffled_valid_fixed.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (400, 640, 128) (400, 4)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 2300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Folk

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 16
num_classes = 4
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 16
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Building model...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3661: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3144: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3014: The name tf.log is deprecated. Please use tf.math.log instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_1 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_2 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_3 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# _________________________________________________________________
# output_realtime (Activation) (None, 4)                 0
# =================================================================
# Total params: 133,260
# Trainable params: 132,924
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 3198 samples, validate on 400 samples
# Epoch 1/70
# 3198/3198 [==============================] - 37s 12ms/step - loss: 1.4013 - acc: 0.5316 - val_loss: 1.2879 - val_acc: 0.5600
#
# Epoch 00001: val_acc improved from -inf to 0.56000, saving model to ./models/crnn/weights.best.h5
# Epoch 2/70
# 3198/3198 [==============================] - 33s 10ms/step - loss: 1.2738 - acc: 0.6113 - val_loss: 2.0089 - val_acc: 0.3100
#
# Epoch 00002: val_acc did not improve from 0.56000
# Epoch 3/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 1.2143 - acc: 0.6332 - val_loss: 1.4752 - val_acc: 0.4900
#
# Epoch 00003: val_acc did not improve from 0.56000
# Epoch 4/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 1.1607 - acc: 0.6582 - val_loss: 1.1850 - val_acc: 0.5900
#
# Epoch 00004: val_acc improved from 0.56000 to 0.59000, saving model to ./models/crnn/weights.best.h5
# Epoch 5/70
# 3198/3198 [==============================] - 35s 11ms/step - loss: 1.1388 - acc: 0.6523 - val_loss: 1.1599 - val_acc: 0.5950
#
# Epoch 00005: val_acc improved from 0.59000 to 0.59500, saving model to ./models/crnn/weights.best.h5
# Epoch 6/70
# 3198/3198 [==============================] - 32s 10ms/step - loss: 1.0989 - acc: 0.6545 - val_loss: 1.0754 - val_acc: 0.6600
#
# Epoch 00006: val_acc improved from 0.59500 to 0.66000, saving model to ./models/crnn/weights.best.h5
# Epoch 7/70
# 3198/3198 [==============================] - 38s 12ms/step - loss: 1.0784 - acc: 0.6714 - val_loss: 1.4533 - val_acc: 0.4625
#
# Epoch 00007: val_acc did not improve from 0.66000
# Epoch 8/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 1.0485 - acc: 0.6773 - val_loss: 1.2069 - val_acc: 0.5725
#
# Epoch 00008: val_acc did not improve from 0.66000
# Epoch 9/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 1.0301 - acc: 0.6767 - val_loss: 1.2199 - val_acc: 0.5775
#
# Epoch 00009: val_acc did not improve from 0.66000
# Epoch 10/70
# 3198/3198 [==============================] - 28s 9ms/step - loss: 1.0118 - acc: 0.6782 - val_loss: 0.9801 - val_acc: 0.6775
#
# Epoch 00010: val_acc improved from 0.66000 to 0.67750, saving model to ./models/crnn/weights.best.h5
# Epoch 11/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.9978 - acc: 0.6823 - val_loss: 1.2643 - val_acc: 0.5050
#
# Epoch 00011: val_acc did not improve from 0.67750
# Epoch 12/70
# 3198/3198 [==============================] - 32s 10ms/step - loss: 1.0087 - acc: 0.6879 - val_loss: 1.0777 - val_acc: 0.5850
#
# Epoch 00012: val_acc did not improve from 0.67750
# Epoch 13/70
# 3198/3198 [==============================] - 32s 10ms/step - loss: 0.9734 - acc: 0.6901 - val_loss: 1.1259 - val_acc: 0.6100
#
# Epoch 00013: val_acc did not improve from 0.67750
# Epoch 14/70
# 3198/3198 [==============================] - 32s 10ms/step - loss: 1.0068 - acc: 0.6660 - val_loss: 1.0022 - val_acc: 0.6550
#
# Epoch 00014: val_acc did not improve from 0.67750
# Epoch 15/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.9675 - acc: 0.6895 - val_loss: 0.9947 - val_acc: 0.6400
#
# Epoch 00015: val_acc did not improve from 0.67750
# Epoch 16/70
# 3198/3198 [==============================] - 30s 10ms/step - loss: 0.9499 - acc: 0.6936 - val_loss: 1.0501 - val_acc: 0.6175
#
# Epoch 00016: val_acc did not improve from 0.67750
# Epoch 17/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.9691 - acc: 0.6795 - val_loss: 1.7306 - val_acc: 0.3350
#
# Epoch 00017: val_acc did not improve from 0.67750
# Epoch 18/70
# 3198/3198 [==============================] - 28s 9ms/step - loss: 0.9300 - acc: 0.6932 - val_loss: 1.4840 - val_acc: 0.4875
#
# Epoch 00018: val_acc did not improve from 0.67750
# Epoch 19/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 0.9304 - acc: 0.7011 - val_loss: 1.0331 - val_acc: 0.6500
#
# Epoch 00019: val_acc did not improve from 0.67750
# Epoch 20/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 0.9312 - acc: 0.6939 - val_loss: 1.3255 - val_acc: 0.5225
#
# Epoch 00020: val_acc did not improve from 0.67750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/70
# 3198/3198 [==============================] - 34s 11ms/step - loss: 0.8826 - acc: 0.7142 - val_loss: 1.0673 - val_acc: 0.6250
#
# Epoch 00021: val_acc did not improve from 0.67750
# Epoch 22/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 0.8667 - acc: 0.7154 - val_loss: 0.9347 - val_acc: 0.6800
#
# Epoch 00022: val_acc improved from 0.67750 to 0.68000, saving model to ./models/crnn/weights.best.h5
# Epoch 23/70
# 3198/3198 [==============================] - 32s 10ms/step - loss: 0.8506 - acc: 0.7208 - val_loss: 1.0113 - val_acc: 0.6625
#
# Epoch 00023: val_acc did not improve from 0.68000
# Epoch 24/70
# 3198/3198 [==============================] - 34s 11ms/step - loss: 0.8477 - acc: 0.7176 - val_loss: 0.9532 - val_acc: 0.6625
#
# Epoch 00024: val_acc did not improve from 0.68000
# Epoch 25/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.8368 - acc: 0.7267 - val_loss: 0.9293 - val_acc: 0.6750
#
# Epoch 00025: val_acc did not improve from 0.68000
# Epoch 26/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.8444 - acc: 0.7280 - val_loss: 1.2907 - val_acc: 0.5700
#
# Epoch 00026: val_acc did not improve from 0.68000
# Epoch 27/70
# 3198/3198 [==============================] - 31s 10ms/step - loss: 0.8168 - acc: 0.7364 - val_loss: 0.8881 - val_acc: 0.6750
#
# Epoch 00027: val_acc did not improve from 0.68000
# Epoch 28/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.8264 - acc: 0.7333 - val_loss: 0.9548 - val_acc: 0.6425
#
# Epoch 00028: val_acc did not improve from 0.68000
# Epoch 29/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.8162 - acc: 0.7264 - val_loss: 0.8997 - val_acc: 0.6775
#
# Epoch 00029: val_acc did not improve from 0.68000
# Epoch 30/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.8097 - acc: 0.7308 - val_loss: 0.9998 - val_acc: 0.6175
#
# Epoch 00030: val_acc did not improve from 0.68000
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 31/70
# 3198/3198 [==============================] - 28s 9ms/step - loss: 0.7609 - acc: 0.7477 - val_loss: 0.9045 - val_acc: 0.6900
#
# Epoch 00031: val_acc improved from 0.68000 to 0.69000, saving model to ./models/crnn/weights.best.h5
# Epoch 32/70
# 3198/3198 [==============================] - 28s 9ms/step - loss: 0.7504 - acc: 0.7505 - val_loss: 0.8720 - val_acc: 0.6825
#
# Epoch 00032: val_acc did not improve from 0.69000
# Epoch 33/70
# 3198/3198 [==============================] - 28s 9ms/step - loss: 0.7544 - acc: 0.7452 - val_loss: 1.0237 - val_acc: 0.6725
#
# Epoch 00033: val_acc did not improve from 0.69000
# Epoch 34/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7538 - acc: 0.7523 - val_loss: 0.9957 - val_acc: 0.6625
#
# Epoch 00034: val_acc did not improve from 0.69000
# Epoch 35/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7422 - acc: 0.7620 - val_loss: 0.9029 - val_acc: 0.6575
#
# Epoch 00035: val_acc did not improve from 0.69000
# Epoch 36/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7409 - acc: 0.7627 - val_loss: 0.8925 - val_acc: 0.6950
#
# Epoch 00036: val_acc improved from 0.69000 to 0.69500, saving model to ./models/crnn/weights.best.h5
# Epoch 37/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7261 - acc: 0.7542 - val_loss: 0.8312 - val_acc: 0.7225
#
# Epoch 00037: val_acc improved from 0.69500 to 0.72250, saving model to ./models/crnn/weights.best.h5
# Epoch 38/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.7190 - acc: 0.7655 - val_loss: 0.8991 - val_acc: 0.6825
#
# Epoch 00038: val_acc did not improve from 0.72250
# Epoch 39/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7095 - acc: 0.7714 - val_loss: 0.8330 - val_acc: 0.7025
#
# Epoch 00039: val_acc did not improve from 0.72250
# Epoch 40/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7388 - acc: 0.7727 - val_loss: 0.9107 - val_acc: 0.6975
#
# Epoch 00040: val_acc did not improve from 0.72250
# Epoch 41/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.7255 - acc: 0.7630 - val_loss: 0.8223 - val_acc: 0.7250
#
# Epoch 00041: val_acc improved from 0.72250 to 0.72500, saving model to ./models/crnn/weights.best.h5
# Epoch 42/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.7197 - acc: 0.7598 - val_loss: 1.0406 - val_acc: 0.6100
#
# Epoch 00042: val_acc did not improve from 0.72500
# Epoch 43/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.7104 - acc: 0.7611 - val_loss: 0.9708 - val_acc: 0.6750
#
# Epoch 00043: val_acc did not improve from 0.72500
# Epoch 44/70
# 3198/3198 [==============================] - 30s 9ms/step - loss: 0.7118 - acc: 0.7786 - val_loss: 1.3905 - val_acc: 0.5825
#
# Epoch 00044: val_acc did not improve from 0.72500
# Epoch 45/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6926 - acc: 0.7739 - val_loss: 1.5987 - val_acc: 0.5325
#
# Epoch 00045: val_acc did not improve from 0.72500
# Epoch 46/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.7131 - acc: 0.7614 - val_loss: 1.3648 - val_acc: 0.6175
#
# Epoch 00046: val_acc did not improve from 0.72500
# Epoch 47/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6984 - acc: 0.7711 - val_loss: 0.8949 - val_acc: 0.6950
#
# Epoch 00047: val_acc did not improve from 0.72500
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 48/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6623 - acc: 0.7930 - val_loss: 0.8236 - val_acc: 0.7300
#
# Epoch 00048: val_acc improved from 0.72500 to 0.73000, saving model to ./models/crnn/weights.best.h5
# Epoch 49/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6612 - acc: 0.7874 - val_loss: 1.0516 - val_acc: 0.6575
#
# Epoch 00049: val_acc did not improve from 0.73000
# Epoch 50/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6287 - acc: 0.7942 - val_loss: 0.9992 - val_acc: 0.6850
#
# Epoch 00050: val_acc did not improve from 0.73000
# Epoch 51/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6251 - acc: 0.7964 - val_loss: 0.8976 - val_acc: 0.6875
#
# Epoch 00051: val_acc did not improve from 0.73000
# Epoch 52/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6611 - acc: 0.7908 - val_loss: 0.8641 - val_acc: 0.6925
#
# Epoch 00052: val_acc did not improve from 0.73000
# Epoch 53/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6510 - acc: 0.7908 - val_loss: 1.0038 - val_acc: 0.6125
#
# Epoch 00053: val_acc did not improve from 0.73000
# Epoch 54/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6448 - acc: 0.7892 - val_loss: 0.8698 - val_acc: 0.7025
#
# Epoch 00054: val_acc did not improve from 0.73000
# Epoch 55/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6238 - acc: 0.7986 - val_loss: 0.8414 - val_acc: 0.7075
#
# Epoch 00055: val_acc did not improve from 0.73000
# Epoch 56/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6255 - acc: 0.7971 - val_loss: 0.9187 - val_acc: 0.6975
#
# Epoch 00056: val_acc did not improve from 0.73000
# Epoch 57/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6249 - acc: 0.8018 - val_loss: 0.8157 - val_acc: 0.7250
#
# Epoch 00057: val_acc did not improve from 0.73000
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 58/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6079 - acc: 0.8039 - val_loss: 0.8188 - val_acc: 0.7200
#
# Epoch 00058: val_acc did not improve from 0.73000
# Epoch 59/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6008 - acc: 0.8068 - val_loss: 0.8863 - val_acc: 0.7100
#
# Epoch 00059: val_acc did not improve from 0.73000
# Epoch 60/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6156 - acc: 0.7996 - val_loss: 0.8845 - val_acc: 0.7025
#
# Epoch 00060: val_acc did not improve from 0.73000
# Epoch 61/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5972 - acc: 0.8055 - val_loss: 0.8421 - val_acc: 0.7300
#
# Epoch 00061: val_acc did not improve from 0.73000
# Epoch 62/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5913 - acc: 0.8180 - val_loss: 0.8278 - val_acc: 0.7250
#
# Epoch 00062: val_acc did not improve from 0.73000
# Epoch 63/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5898 - acc: 0.8108 - val_loss: 0.8824 - val_acc: 0.7175
#
# Epoch 00063: val_acc did not improve from 0.73000
# Epoch 64/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.6002 - acc: 0.8011 - val_loss: 0.8439 - val_acc: 0.7175
#
# Epoch 00064: val_acc did not improve from 0.73000
# Epoch 65/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5914 - acc: 0.8080 - val_loss: 0.8515 - val_acc: 0.7200
#
# Epoch 00065: val_acc did not improve from 0.73000
# Epoch 66/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5822 - acc: 0.8143 - val_loss: 0.8264 - val_acc: 0.7425
#
# Epoch 00066: val_acc improved from 0.73000 to 0.74250, saving model to ./models/crnn/weights.best.h5
# Epoch 67/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5701 - acc: 0.8111 - val_loss: 0.8575 - val_acc: 0.7125
#
# Epoch 00067: val_acc did not improve from 0.74250
# Epoch 68/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5713 - acc: 0.8230 - val_loss: 0.8460 - val_acc: 0.7300
#
# Epoch 00068: val_acc did not improve from 0.74250
# Epoch 69/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5987 - acc: 0.8052 - val_loss: 0.8814 - val_acc: 0.6925
#
# Epoch 00069: val_acc did not improve from 0.74250
# Epoch 70/70
# 3198/3198 [==============================] - 29s 9ms/step - loss: 0.5753 - acc: 0.8199 - val_loss: 1.0355 - val_acc: 0.6775
#
# Epoch 00070: val_acc did not improve from 0.74250

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (400,) (400,)
#               precision    recall  f1-score   support
#
#   Electronic       0.65      0.84      0.73       100
#         Rock       0.66      0.52      0.58       100
# Instrumental       0.74      0.45      0.56       100
#         Folk       0.69      0.90      0.78       100
#
#     accuracy                           0.68       400
#    macro avg       0.68      0.68      0.66       400
# weighted avg       0.68      0.68      0.66       400

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.6775

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (400, 640, 128) (400,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 3 1.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0 0.005244339269680282

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (400,) (400,)
#               precision    recall  f1-score   support
#
#   Electronic       0.81      0.81      0.81       100
#         Rock       0.69      0.68      0.69       100
# Instrumental       0.39      0.42      0.40       100
#         Folk       0.37      0.34      0.35       100
#
#     accuracy                           0.56       400
#    macro avg       0.56      0.56      0.56       400
# weighted avg       0.56      0.56      0.56       400

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=4)
model.evaluate(X_test, y_test)
# Out:
# 400/400 [==============================] - 1s 3ms/step
# [1.5238433218002319, 0.5625]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[81  2  6 11]
#  [ 9 68 11 12]
#  [ 6 16 42 36]
#  [ 4 12 50 34]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.5625

# %%
print(y_true.shape, y_pred.shape)
# Out:
# (400,) (400,)

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns

mat = confusion_matrix(y_true, y_pred)
z = np.zeros(4, int)
a = np.insert(mat.T, 0, [z], axis=0)
a = np.append(a, [z], axis=0)
sns.heatmap(a, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=[''] + list(dict_genres.keys()) + [''])
plt.xlabel('True class')
plt.ylabel('Predicted class');
